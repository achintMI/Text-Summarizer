# %%
import nltk, re, pprint
from nltk import word_tokenize

# %%
inline = open('test.txt', 'r')
text = inline.read().decode('utf8')
print(text[:1000])
type(text)
# Out:
# Harry Potter and the Sorcerer's Stone
#
# CHAPTER ONE
#
# THE BOY WHO LIVED
#
# Mr. and Mrs. Dursley, of number four, Privet Drive, were proud to say that they were perfectly normal, thank you very much. They were the last people you'd expect to be involved in anything strange or mysterious, because they just didn't hold with such nonsense.
#
# Mr. Dursley was the director of a firm called Grunnings, which made drills. He was a big, beefy man with hardly any neck, although he did have a very large mustache. Mrs. Dursley was thin and blonde and had nearly twice the usual amount of neck, which came in very useful as she spent so much of her time craning over garden fences, spying on the neighbors. The Dursleys had a small son called Dudley and in their opinion there was no finer boy anywhere.
#
# The Dursleys had everything they wanted, but they also had a secret, and their greatest fear was that somebody would discover it. They didn't think they could bear it if anyone found out about t
# unicode

# %%
tokens = word_tokenize(text)
print(type(tokens), len(tokens) )
# print(tokens[:10])
# Out:
# (<type 'list'>, 98841)

# %%
tokens
# Out:
# [u'Harry',
#  u'Potter',
#  u'and',
#  u'the',
#  u'Sorcerer',
#  u"'s",
#  u'Stone',
#  u'CHAPTER',
#  u'ONE',
#  u'THE',
#  u'BOY',
#  u'WHO',
#  u'LIVED',
#  u'Mr.',
#  u'and',
#  u'Mrs.',
#  u'Dursley',
#  u',',
#  u'of',
#  u'number',
#  u'four',
#  u',',
#  u'Privet',
#  u'Drive',
#  u',',
#  u'were',
#  u'proud',
#  u'to',
#  u'say',
#  u'that',
#  u'they',
#  u'were',
#  u'perfectly',
#  u'normal',
#  u',',
#  u'thank',
#  u'you',
#  u'very',
#  u'much',
#  u'.',
#  u'They',
#  u'were',
#  u'the',
#  u'last',
#  u'people',
#  u'you',
#  u"'d",
#  u'expect',
#  u'to',
#  u'be',
#  u'involved',
#  u'in',
#  u'anything',
#  u'strange',
#  u'or',
#  u'mysterious',
#  u',',
#  u'because',
#  u'they',
#  u'just',
#  u'did',
#  u"n't",
#  u'hold',
#  u'with',
#  u'such',
#  u'nonsense',
#  u'.',
#  u'Mr.',
#  u'Dursley',
#  u'was',
#  u'the',
#  u'director',
#  u'of',
#  u'a',
#  u'firm',
#  u'called',
#  u'Grunnings',
#  u',',
#  u'which',
#  u'made',
#  u'drills',
#  u'.',
#  u'He',
#  u'was',
#  u'a',
#  u'big',
#  u',',
#  u'beefy',
#  u'man',
#  u'with',
#  u'hardly',
#  u'any',
#  u'neck',
#  u',',
#  u'although',
#  u'he',
#  u'did',
#  u'have',
#  u'a',
#  u'very',
#  u'large',
#  u'mustache',
#  u'.',
#  u'Mrs.',
#  u'Dursley',
#  u'was',
#  u'thin',
#  u'and',
#  u'blonde',
#  u'and',
#  u'had',
#  u'nearly',
#  u'twice',
#  u'the',
#  u'usual',
#  u'amount',
#  u'of',
#  u'neck',
#  u',',
#  u'which',
#  u'came',
#  u'in',
#  u'very',
#  u'useful',
#  u'as',
#  u'she',
#  u'spent',
#  u'so',
#  u'much',
#  u'of',
#  u'her',
#  u'time',
#  u'craning',
#  u'over',
#  u'garden',
#  u'fences',
#  u',',
#  u'spying',
#  u'on',
#  u'the',
#  u'neighbors',
#  u'.',
#  u'The',
#  u'Dursleys',
#  u'had',
#  u'a',
#  u'small',
#  u'son',
#  u'called',
#  u'Dudley',
#  u'and',
#  u'in',
#  u'their',
#  u'opinion',
#  u'there',
#  u'was',
#  u'no',
#  u'finer',
#  u'boy',
#  u'anywhere',
#  u'.',
#  u'The',
#  u'Dursleys',
#  u'had',
#  u'everything',
#  u'they',
#  u'wanted',
#  u',',
#  u'but',
#  u'they',
#  u'also',
#  u'had',
#  u'a',
#  u'secret',
#  u',',
#  u'and',
#  u'their',
#  u'greatest',
#  u'fear',
#  u'was',
#  u'that',
#  u'somebody',
#  u'would',
#  u'discover',
#  u'it',
#  u'.',
#  u'They',
#  u'did',
#  u"n't",
#  u'think',
#  u'they',
#  u'could',
#  u'bear',
#  u'it',
#  u'if',
#  u'anyone',
#  u'found',
#  u'out',
#  u'about',
#  u'the',
#  u'Potters',
#  u'.',
#  u'Mrs.',
#  u'Potter',
#  u'was',
#  u'Mrs.',
#  u'Dursley',
#  u"'s",
#  u'sister',
#  u',',
#  u'but',
#  u'they',
#  u'had',
#  u"n't",
#  u'met',
#  u'for',
#  u'several',
#  u'years',
#  u';',
#  u'in',
#  u'fact',
#  u',',
#  u'Mrs.',
#  u'Dursley',
#  u'pretended',
#  u'she',
#  u'did',
#  u"n't",
#  u'have',
#  u'a',
#  u'sister',
#  u',',
#  u'because',
#  u'her',
#  u'sister',
#  u'and',
#  u'her',
#  u'good-for-nothing',
#  u'husband',
#  u'were',
#  u'as',
#  u'unDursleyish',
#  u'as',
#  u'it',
#  u'was',
#  u'possible',
#  u'to',
#  u'be',
#  u'.',
#  u'The',
#  u'Dursleys',
#  u'shuddered',
#  u'to',
#  u'think',
#  u'what',
#  u'the',
#  u'neighbors',
#  u'would',
#  u'say',
#  u'if',
#  u'the',
#  u'Potters',
#  u'arrived',
#  u'in',
#  u'the',
#  u'street',
#  u'.',
#  u'The',
#  u'Dursleys',
#  u'knew',
#  u'that',
#  u'the',
#  u'Potters',
#  u'had',
#  u'a',
#  u'small',
#  u'son',
#  u',',
#  u'too',
#  u',',
#  u'but',
#  u'they',
#  u'had',
#  u'never',
#  u'even',
#  u'seen',
#  u'him',
#  u'.',
#  u'This',
#  u'boy',
#  u'was',
#  u'another',
#  u'good',
#  u'reason',
#  u'for',
#  u'keeping',
#  u'the',
#  u'Potters',
#  u'away',
#  u';',
#  u'they',
#  u'did',
#  u"n't",
#  u'want',
#  u'Dudley',
#  u'mixing',
#  u'with',
#  u'a',
#  u'child',
#  u'like',
#  u'that',
#  u'.',
#  u'When',
#  u'Mr.',
#  u'and',
#  u'Mrs.',
#  u'Dursley',
#  u'woke',
#  u'up',
#  u'on',
#  u'the',
#  u'dull',
#  u',',
#  u'gray',
#  u'Tuesday',
#  u'our',
#  u'story',
#  u'starts',
#  u',',
#  u'there',
#  u'was',
#  u'nothing',
#  u'about',
#  u'the',
#  u'cloudy',
#  u'sky',
#  u'outside',
#  u'to',
#  u'suggest',
#  u'that',
#  u'strange',
#  u'and',
#  u'mysterious',
#  u'things',
#  u'would',
#  u'soon',
#  u'be',
#  u'happening',
#  u'all',
#  u'over',
#  u'the',
#  u'country',
#  u'.',
#  u'Mr.',
#  u'Dursley',
#  u'hummed',
#  u'as',
#  u'he',
#  u'picked',
#  u'out',
#  u'his',
#  u'most',
#  u'boring',
#  u'tie',
#  u'for',
#  u'work',
#  u',',
#  u'and',
#  u'Mrs.',
#  u'Dursley',
#  u'gossiped',
#  u'away',
#  u'happily',
#  u'as',
#  u'she',
#  u'wrestled',
#  u'a',
#  u'screaming',
#  u'Dudley',
#  u'into',
#  u'his',
#  u'high',
#  u'chair',
#  u'.',
#  u'None',
#  u'of',
#  u'them',
#  u'noticed',
#  u'a',
#  u'large',
#  u',',
#  u'tawny',
#  u'owl',
#  u'flutter',
#  u'past',
#  u'the',
#  u'window',
#  u'.',
#  u'At',
#  u'half',
#  u'past',
#  u'eight',
#  u',',
#  u'Mr.',
#  u'Dursley',
#  u'picked',
#  u'up',
#  u'his',
#  u'briefcase',
#  u',',
#  u'pecked',
#  u'Mrs.',
#  u'Dursley',
#  u'on',
#  u'the',
#  u'cheek',
#  u',',
#  u'and',
#  u'tried',
#  u'to',
#  u'kiss',
#  u'Dudley',
#  u'good-bye',
#  u'but',
#  u'missed',
#  u',',
#  u'because',
#  u'Dudley',
#  u'was',
#  u'now',
#  u'having',
#  u'a',
#  u'tantrum',
#  u'and',
#  u'throwing',
#  u'his',
#  u'cereal',
#  u'at',
#  u'the',
#  u'walls',
#  u'.',
#  u'``',
#  u'Little',
#  u'tyke',
#  u',',
#  u"''",
#  u'chortled',
#  u'Mr.',
#  u'Dursley',
#  u'as',
#  u'he',
#  u'left',
#  u'the',
#  u'house',
#  u'.',
#  u'He',
#  u'got',
#  u'into',
#  u'his',
#  u'car',
#  u'and',
#  u'backed',
#  u'out',
#  u'of',
#  u'number',
#  u'four',
#  u"'s",
#  u'drive',
#  u'.',
#  u'It',
#  u'was',
#  u'on',
#  u'the',
#  u'corner',
#  u'of',
#  u'the',
#  u'street',
#  u'that',
#  u'he',
#  u'noticed',
#  u'the',
#  u'first',
#  u'sign',
#  u'of',
#  u'something',
#  u'peculiar',
#  u'--',
#  u'a',
#  u'cat',
#  u'reading',
#  u'a',
#  u'map',
#  u'.',
#  u'For',
#  u'a',
#  u'second',
#  u',',
#  u'Mr.',
#  u'Dursley',
#  u'did',
#  u"n't",
#  u'realize',
#  u'what',
#  u'he',
#  u'had',
#  u'seen',
#  u'--',
#  u'then',
#  u'he',
#  u'jerked',
#  u'his',
#  u'head',
#  u'around',
#  u'to',
#  u'look',
#  u'again',
#  u'.',
#  u'There',
#  u'was',
#  u'a',
#  u'tabby',
#  u'cat',
#  u'standing',
#  u'on',
#  u'the',
#  u'corner',
#  u'of',
#  u'Privet',
#  u'Drive',
#  u',',
#  u'but',
#  u'there',
#  u'was',
#  u"n't",
#  u'a',
#  u'map',
#  u'in',
#  u'sight',
#  u'.',
#  u'What',
#  u'could',
#  u'he',
#  u'have',
#  u'been',
#  u'thinking',
#  u'of',
#  u'?',
#  u'It',
#  u'must',
#  u'have',
#  u'been',
#  u'a',
#  u'trick',
#  u'of',
#  u'the',
#  u'light',
#  u'.',
#  u'Mr.',
#  u'Dursley',
#  u'blinked',
#  u'and',
#  u'stared',
#  u'at',
#  u'the',
#  u'cat',
#  u'.',
#  u'It',
#  u'stared',
#  u'back',
#  u'.',
#  u'As',
#  u'Mr.',
#  u'Dursley',
#  u'drove',
#  u'around',
#  u'the',
#  u'corner',
#  u'and',
#  u'up',
#  u'the',
#  u'road',
#  u',',
#  u'he',
#  u'watched',
#  u'the',
#  u'cat',
#  u'in',
#  u'his',
#  u'mirror',
#  u'.',
#  u'It',
#  u'was',
#  u'now',
#  u'reading',
#  u'the',
#  u'sign',
#  u'that',
#  u'said',
#  u'Privet',
#  u'Drive',
#  u'--',
#  u'no',
#  u',',
#  u'looking',
#  u'at',
#  u'the',
#  u'sign',
#  u';',
#  u'cats',
#  u'could',
#  u"n't",
#  u'read',
#  u'maps',
#  u'or',
#  u'signs',
#  u'.',
#  u'Mr.',
#  u'Dursley',
#  u'gave',
#  u'himself',
#  u'a',
#  u'little',
#  u'shake',
#  u'and',
#  u'put',
#  u'the',
#  u'cat',
#  u'out',
#  u'of',
#  u'his',
#  u'mind',
#  u'.',
#  u'As',
#  u'he',
#  u'drove',
#  u'toward',
#  u'town',
#  u'he',
#  u'thought',
#  u'of',
#  u'nothing',
#  u'except',
#  u'a',
#  u'large',
#  u'order',
#  u'of',
#  u'drills',
#  u'he',
#  u'was',
#  u'hoping',
#  u'to',
#  u'get',
#  u'that',
#  u'day',
#  u'.',
#  u'But',
#  u'on',
#  u'the',
#  u'edge',
#  u'of',
#  u'town',
#  u',',
#  u'drills',
#  u'were',
#  u'driven',
#  u'out',
#  u'of',
#  u'his',
#  u'mind',
#  u'by',
#  u'something',
#  u'else',
#  u'.',
#  u'As',
#  u'he',
#  u'sat',
#  u'in',
#  u'the',
#  u'usual',
#  u'morning',
#  u'traffic',
#  u'jam',
#  u',',
#  u'he',
#  u'could',
#  u"n't",
#  u'help',
#  u'noticing',
#  u'that',
#  u'there',
#  u'seemed',
#  u'to',
#  u'be',
#  u'a',
#  u'lot',
#  u'of',
#  u'strangely',
#  u'dressed',
#  u'people',
#  u'about',
#  u'.',
#  u'People',
#  u'in',
#  u'cloaks',
#  u'.',
#  u'Mr.',
#  u'Dursley',
#  u'could',
#  u"n't",
#  u'bear',
#  u'people',
#  u'who',
#  u'dressed',
#  u'in',
#  u'funny',
#  u'clothes',
#  u'--',
#  u'the',
#  u'getups',
#  u'you',
#  u'saw',
#  u'on',
#  u'young',
#  u'people',
#  u'!',
#  u'He',
#  u'supposed',
#  u'this',
#  u'was',
#  u'some',
#  u'stupid',
#  u'new',
#  u'fashion',
#  u'.',
#  u'He',
#  u'drummed',
#  u'his',
#  u'fingers',
#  u'on',
#  u'the',
#  u'steering',
#  u'wheel',
#  u'and',
#  u'his',
#  u'eyes',
#  u'fell',
#  u'on',
#  u'a',
#  u'huddle',
#  u'of',
#  u'these',
#  u'weirdos',
#  u'standing',
#  u'quite',
#  u'close',
#  u'by',
#  u'.',
#  u'They',
#  u'were',
#  u'whispering',
#  u'excitedly',
#  u'together',
#  u'.',
#  u'Mr.',
#  u'Dursley',
#  u'was',
#  u'enraged',
#  u'to',
#  u'see',
#  u'that',
#  u'a',
#  u'couple',
#  u'of',
#  u'them',
#  u'were',
#  u"n't",
#  u'young',
#  u'at',
#  u'all',
#  u';',
#  u'why',
#  u',',
#  u'that',
#  u'man',
#  u'had',
#  u'to',
#  u'be',
#  u'older',
#  u'than',
#  u'he',
#  u'was',
#  u',',
#  u'and',
#  u'wearing',
#  u'an',
#  u'emerald-green',
#  u'cloak',
#  u'!',
#  u'The',
#  u'nerve',
#  u'of',
#  u'him',
#  u'!',
#  u'But',
#  u'then',
#  u'it',
#  u'struck',
#  u'Mr.',
#  u'Dursley',
#  u'that',
#  u'this',
#  u'was',
#  u'probably',
#  u'some',
#  u'silly',
#  u'stunt',
#  u'--',
#  u'these',
#  u'people',
#  u'were',
#  u'obviously',
#  u'collecting',
#  u'for',
#  u'something',
#  u'...',
#  u'yes',
#  u',',
#  u'that',
#  u'would',
#  u'be',
#  u'it',
#  u'.',
#  u'The',
#  u'traffic',
#  u'moved',
#  u'on',
#  u'and',
#  u'a',
#  u'few',
#  u'minutes',
#  u'later',
#  u',',
#  u'Mr.',
#  u'Dursley',
#  u'arrived',
#  u'in',
#  u'the',
#  u'Grunnings',
#  u'parking',
#  u'lot',
#  u',',
#  u'his',
#  u'mind',
#  u'back',
#  u'on',
#  u'drills',
#  u'.',
#  u'Mr.',
#  u'Dursley',
#  u'always',
#  u'sat',
#  u'with',
#  u'his',
#  u'back',
#  u'to',
#  u'the',
#  u'window',
#  u'in',
#  u'his',
#  u'office',
#  u'on',
#  u'the',
#  u'ninth',
#  u'floor',
#  u'.',
#  u'If',
#  u'he',
#  u'had',
#  u"n't",
#  u',',
#  u'he',
#  u'might',
#  u'have',
#  u'found',
#  u'it',
#  u'harder',
#  u'to',
#  u'concentrate',
#  u'on',
#  u'drills',
#  u'that',
#  u'morning',
#  u'.',
#  u'He',
#  u'did',
#  u"n't",
#  u'see',
#  u'the',
#  u'owls',
#  u'swoop',
#  u'ing',
#  u'past',
#  u'in',
#  u'broad',
#  u'daylight',
#  u',',
#  u'though',
#  u'people',
#  u'down',
#  u'in',
#  u'the',
#  u'street',
#  u'did',
#  u';',
#  u'they',
#  u'pointed',
#  u'and',
#  u'gazed',
#  u'open-',
#  u'mouthed',
#  u'as',
#  u'owl',
#  u'after',
#  u'owl',
#  u'sped',
#  u'overhead',
#  u'.',
#  u'Most',
#  u'of',
#  u'them',
#  u'had',
#  u'never',
#  u'seen',
#  u'an',
#  u'owl',
#  u'even',
#  u'at',
#  u'nighttime',
#  u'.',
#  u'Mr.',
#  u'Dursley',
#  u',',
#  u'however',
#  u',',
#  u'had',
#  u'a',
#  u'perfectly',
#  u'normal',
#  u',',
#  u'owl-free',
#  u'morning',
#  u'.',
#  u'He',
#  u'yelled',
#  u'at',
#  u'five',
#  u'different',
#  u'people',
#  u'.',
#  u'He',
#  u'made',
#  u'several',
#  u'important',
#  u'telephone',
#  u'calls',
#  u'and',
#  u'shouted',
#  u'a',
#  u'bit',
#  u'more',
#  u'.',
#  u'He',
#  u'was',
#  u'in',
#  u'a',
#  u'very',
#  u'good',
#  u'mood',
#  u'until',
#  u'lunchtime',
#  u',',
#  u'when',
#  u'he',
#  u'thought',
#  u'he',
#  u"'d",
#  u'stretch',
#  u'his',
#  u'legs',
#  u'and',
#  u'walk',
#  u'across',
#  u'the',
#  u'road',
#  u'to',
#  u'buy',
#  u'himself',
#  u'a',
#  u'bun',
#  u'from',
#  ...]

# %%
WHITELIST ='0123456789abcdefghijklmnopqrstuvwxyz '
VOCAB_SIZE = 1200
UNK = 'unk'
limit = {
    'max_descriptions' : 400,
    'min_descriptions' : 0,
    'max_headings' : 20,
    'min_headings' : 0,
}

# %%
import json
with open('test.txt', 'r') as fp:
    raw_data = json.load(fp)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-23ddb485948a> in <module>()
#       1 import json
#       2 with open('test.txt', 'r') as fp:
# ----> 3     raw_data = json.load(fp)
#
# /home/achint/miniconda2/lib/python2.7/json/__init__.pyc in load(fp, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     289         parse_float=parse_float, parse_int=parse_int,
#     290         parse_constant=parse_constant, object_pairs_hook=object_pairs_hook,
# --> 291         **kw)
#     292
#     293
#
# /home/achint/miniconda2/lib/python2.7/json/__init__.pyc in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     337             parse_int is None and parse_float is None and
#     338             parse_constant is None and object_pairs_hook is None and not kw):
# --> 339         return _default_decoder.decode(s)
#     340     if cls is None:
#     341         cls = JSONDecoder
#
# /home/achint/miniconda2/lib/python2.7/json/decoder.pyc in decode(self, s, _w)
#     362
#     363         """
# --> 364         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     365         end = _w(s, end).end()
#     366         if end != len(s):
#
# /home/achint/miniconda2/lib/python2.7/json/decoder.pyc in raw_decode(self, s, idx)
#     380             obj, end = self.scan_once(s, idx)
#     381         except StopIteration:
# --> 382             raise ValueError("No JSON object could be decoded")
#     383         return obj, end
#
# ValueError: No JSON object could be decoded
